# %% [markdown]
# <a href="https://colab.research.google.com/github/uoahy-6uoas/HG-Analysis/blob/main/hg3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# keywords = data-cleaning, data-wrangling, data-munging, element-wise-comparison, boolean-array, numpy

# %%
import gdown

gdown.download('https://bit.ly/3RhoNho', 'ns_202104.csv', quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3RhoNho
# To: /content/ns_202104.csv
# 100%|██████████| 57.6M/57.6M [00:00<00:00, 83.7MB/s]
# 'ns_202104.csv'

# %%
import pandas as pd

ns_df = pd.read_csv('ns_202104.csv', low_memory=False)
ns_df.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN

# %%
ns_book = ns_df.loc[:, '번호':'등록일자']
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
ns_df.columns[0]
# Out:
# '번호'

# %% [markdown]
# > **Element-Wise-Comparision** : Pandas array compare a thing with its each element

# %%
type(ns_df.columns != 'Unnamed: 13')
# Out:
# numpy.ndarray

# %%
selected_columns = ns_df.columns != 'Unnamed: 13'
ns_book = ns_df.loc[:, selected_columns]
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19

# %%
#drop
ns_book = ns_df.drop(['부가기호','Unnamed: 13'], axis=1)
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN    권 주제분류번호  도서권수  대출건수        등록일자
# 0     NaN  NaN    NaN     1     0  2021-03-19
# 1     NaN  NaN    NaN     1     0  2021-03-19
# 2     NaN  NaN    NaN     1     0  2021-03-19
# 3     NaN  NaN    NaN     1     0  2021-03-19
# 4     NaN  NaN    NaN     1     0  2021-03-19

# %%
ns_book.drop('주제분류번호', axis=1, inplace=True) #modify immadiately
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN    권  도서권수  대출건수        등록일자
# 0     NaN  NaN     1     0  2021-03-19
# 1     NaN  NaN     1     0  2021-03-19
# 2     NaN  NaN     1     0  2021-03-19
# 3     NaN  NaN     1     0  2021-03-19
# 4     NaN  NaN     1     0  2021-03-19

# %%
ns_book.dropna(axis=1,how='all') #all col element == nan -> drop
ns_book.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN    권  도서권수  대출건수        등록일자
# 0     NaN  NaN     1     0  2021-03-19
# 1     NaN  NaN     1     0  2021-03-19
# 2     NaN  NaN     1     0  2021-03-19
# 3     NaN  NaN     1     0  2021-03-19
# 4     NaN  NaN     1     0  2021-03-19

# %%
ns_book2 = ns_book.drop([0,1])
ns_book2.head()
# Out:
#    번호                                  도서명                    저자  \
# 2   3                나도 한 문장 잘 쓰면 바랄 게 없겠네                김선영 지음
# 3   4                              예루살렘 해변      이도 게펜 지음, 임재희 옮김
# 4   5                김성곤의 중국한시기행 : 장강·황하 편                김성곤 지음
# 5   6                        처음 읽는 음식의 세계사  미야자키 마사카츠 지음, 한세희 옮김
# 6   7  아르센 벵거 자서전 My Life in Red and White     아르센 벵거 지음, 이성모 옮김
#
#             출판사  발행년도           ISBN 세트 ISBN    권  도서권수  대출건수        등록일자
# 2          블랙피쉬  2021  9788968332982     NaN  NaN     1     0  2021-03-19
# 3         문학세계사  2021  9788970759906     NaN  NaN     1     0  2021-03-19
# 4           김영사  2021  9788934990833     NaN  NaN     1     0  2021-03-19
# 5          탐나는책  2021  9791189550370     NaN  NaN     1     0  2021-03-19
# 6  한즈미디어(한스미디어)  2021  9791160075793     NaN  NaN     1     0  2021-03-19

# %%
selected_rows = ns_df['출판사'] == '한빛미디어'
ns_book2 = ns_book[selected_rows]
ns_book2.head()
# Out:
#       번호                                                도서명  \
# 60    61       (맛있는 디자인)프리미어 프로 CC: 쉽게 배워 제대로 써먹는 유튜브 영상 편집
# 70    71         처음 배우는 애저 (Azure Portal로 배우는 애저 도입부터 활용까지)
# 88    89  맛있는 디자인 프리미어 프로 CC 2021 - 쉽게 배워 제대로 써먹는 유튜브 영상 편집
# 156  157                    실전 보고서 작성 기술 with 파워포인트, 워드, 한글
# 198  199                                    처음 배우는 리액트 네이티브
#
#                            저자    출판사  발행년도           ISBN 세트 ISBN     권  도서권수  \
# 60         정지원,심수진,윤성우,김덕영 지음  한빛미디어  2021  9791162244029     NaN  2021     1
# 70                        김도균  한빛미디어  2020  9791162243695     NaN   NaN     1
# 88   정지원, 심수진, 윤성우, 김덕영 (지은이)  한빛미디어  2021  9791162244029     NaN   NaN     0
# 156                    홍장표 지음  한빛미디어  2020  9791162243763     NaN   NaN     1
# 198                    김범준 지음  한빛미디어  2021  9791162243879     NaN   NaN     1
#
#      대출건수        등록일자
# 60      1  2021-03-15
# 70      1  2021-03-15
# 88      0  2021-03-15
# 156     0  2021-03-12
# ...

# %%
ns_book2 = ns_book[ns_book['대출건수']>1000]
ns_book2.head()
# Out:
#             번호                                      도서명                 저자  \
# 94781    94782  사피엔스 :유인원에서 사이보그까지, 인간 역사의 대담하고 위대한 질문   유발 하라리 지음 ;조현욱 옮김
# 346944  346945                         해커스 토익:Listening       David Cho 지음
#
#              출판사  발행년도           ISBN 세트 ISBN    권  도서권수  대출건수        등록일자
# 94781        김영사  2016  9788934972464     NaN  NaN    30  1468  2016-04-22
# 346944  해커스어학연구소  2005  9788990700148     NaN  NaN    29  1065  2005-02-01

# %%
#finding duplicated element
print(sum(ns_book.duplicated(subset=['도서명','저자','ISBN','권'])))

dup_rows = ns_book.duplicated(subset=['도서명','저자','ISBN','권'],keep=False) #type == nparray, which returns True if duplicated row else False
ns_book3 = ns_book[dup_rows]
ns_book3.head()
# Out:
# 17091
#       번호                  도서명                 저자           출판사  발행년도  \
# 109  110                  파친코     이민진 지음 ;이미정 옮김          문학사상  2018
# 110  111                  파친코     이민진 지음 ;이미정 옮김          문학사상  2018
# 111  112  보건교사 안은영 :정세랑 장편소설            지은이: 정세랑           민음사  2021
# 112  113  보건교사 안은영 :정세랑 장편소설            지은이: 정세랑           민음사  2021
# 113  114                 스토너   존 윌리엄스 지음 ;김승욱 옮김  RHK(알에이치코리아)  2021
#
#               ISBN        세트 ISBN    권  도서권수  대출건수        등록일자
# 109  9788970129815  9788970129808    1     1     0  2021-03-12
# 110  9788970129822  9788970129808    2     1     0  2021-03-12
# 111  9788937479953            NaN  NaN     1     0  2021-03-12
# 112  9788937479953            NaN  NaN     1     1  2021-03-12
# 113  9788925538297            NaN  NaN     1     0  2021-03-12

# %%
#groupby
count_df = ns_book[['도서명','저자','ISBN','권','대출건수']]

group_df = count_df.groupby(by=['도서명','저자','ISBN','권'],dropna=False) # do not drop row containing NaN
loan_count = group_df.sum()

#equal
loan_count = group_df = count_df.groupby(by=['도서명','저자','ISBN','권'],dropna=False).sum()
loan_count.head()
# Out:
#                                                                                             대출건수
# 도서명                                             저자                       ISBN          권
#  (꼭 필요한 것부터 쉽게 배우는) 자신만만 블로그 차근차근 배우기           김상현 지음                   9788955025637 NaN    38
#  (맨처음 배우는) 세상의 직업                               엘레오노라 바르소티 글 ·그림 ;김태은 옮김 9788992924146 NaN    10
#  (영잘원 리스닝과 패턴 영어의 절묘한 만남으로 태어난 ) 리스닝 ABC : 입문편  JD Kim 지음                9788993466089 NaN     4
#  (즉석에서 바로바로 활용하는) 일상생활 베트남어 첫걸음                 FL4U컨텐츠 지음               9788971728000 NaN     3
#  ,에게                                            이기린(이진희)                 9791196137014 NaN     0

# %%
# finding unique row
dup_rows = ns_book.duplicated(subset = ['도서명','저자','ISBN','권'])

unique_rows = ~dup_rows #reverse bool
ns_book3 = ns_book[unique_rows].copy() #copy() : store ns_book3 at another memory space

# %%
#check if dup
sum(ns_book3.duplicated(subset = ['도서명','저자','ISBN','권']))
# Out:
# 0

# %%
#set_index
ns_book3.set_index(['도서명','저자','ISBN','권'],inplace=True)
ns_book3.head()
# Out:
#                                                           번호    출판사  발행년도  \
# 도서명                   저자               ISBN          권
# 인공지능과 흙               김동훈 지음           9788937444319 NaN   1    민음사  2021
# 가짜 행복 권하는 사회          김태형 지음           9791190123969 NaN   2   갈매나무  2021
# 나도 한 문장 잘 쓰면 바랄 게 없겠네 김선영 지음           9788968332982 NaN   3   블랙피쉬  2021
# 예루살렘 해변               이도 게펜 지음, 임재희 옮김 9788970759906 NaN   4  문학세계사  2021
# 김성곤의 중국한시기행 : 장강·황하 편 김성곤 지음           9788934990833 NaN   5    김영사  2021
#
#                                                          세트 ISBN  도서권수  대출건수  \
# 도서명                   저자               ISBN          권
# 인공지능과 흙               김동훈 지음           9788937444319 NaN     NaN     1     0
# 가짜 행복 권하는 사회          김태형 지음           9791190123969 NaN     NaN     1     0
# 나도 한 문장 잘 쓰면 바랄 게 없겠네 김선영 지음           9788968332982 NaN     NaN     1     0
# 예루살렘 해변               이도 게펜 지음, 임재희 옮김 9788970759906 NaN     NaN     1     0
# ...

# %%
ns_book3.update(loan_count)
ns_book3.head()
# Out:
#                                                           번호    출판사  발행년도  \
# 도서명                   저자               ISBN          권
# 인공지능과 흙               김동훈 지음           9788937444319 NaN   1    민음사  2021
# 가짜 행복 권하는 사회          김태형 지음           9791190123969 NaN   2   갈매나무  2021
# 나도 한 문장 잘 쓰면 바랄 게 없겠네 김선영 지음           9788968332982 NaN   3   블랙피쉬  2021
# 예루살렘 해변               이도 게펜 지음, 임재희 옮김 9788970759906 NaN   4  문학세계사  2021
# 김성곤의 중국한시기행 : 장강·황하 편 김성곤 지음           9788934990833 NaN   5    김영사  2021
#
#                                                          세트 ISBN  도서권수  대출건수  \
# 도서명                   저자               ISBN          권
# 인공지능과 흙               김동훈 지음           9788937444319 NaN     NaN     1   0.0
# 가짜 행복 권하는 사회          김태형 지음           9791190123969 NaN     NaN     1   0.0
# 나도 한 문장 잘 쓰면 바랄 게 없겠네 김선영 지음           9788968332982 NaN     NaN     1   0.0
# 예루살렘 해변               이도 게펜 지음, 임재희 옮김 9788970759906 NaN     NaN     1   0.0
# ...

# %%
ns_book4 = ns_book3.reset_index()
ns_book4.head()
# Out:
#                      도서명                저자           ISBN    권  번호    출판사  \
# 0                인공지능과 흙            김동훈 지음  9788937444319  NaN   1    민음사
# 1           가짜 행복 권하는 사회            김태형 지음  9791190123969  NaN   2   갈매나무
# 2  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음  9788968332982  NaN   3   블랙피쉬
# 3                예루살렘 해변  이도 게펜 지음, 임재희 옮김  9788970759906  NaN   4  문학세계사
# 4  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음  9788934990833  NaN   5    김영사
#
#    발행년도 세트 ISBN  도서권수  대출건수        등록일자
# 0  2021     NaN     1   0.0  2021-03-19
# 1  2021     NaN     1   0.0  2021-03-19
# 2  2021     NaN     1   0.0  2021-03-19
# 3  2021     NaN     1   0.0  2021-03-19
# 4  2021     NaN     1   0.0  2021-03-19

# %%
#change to sorting col_name want
ns_book4 = ns_book4[ns_book.columns]
ns_book4.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN    권  도서권수  대출건수        등록일자
# 0     NaN  NaN     1   0.0  2021-03-19
# 1     NaN  NaN     1   0.0  2021-03-19
# 2     NaN  NaN     1   0.0  2021-03-19
# 3     NaN  NaN     1   0.0  2021-03-19
# 4     NaN  NaN     1   0.0  2021-03-19

# %%
#saving ns_book4 to csv
ns_book4.to_csv('ns_book4.csv',index=False)

# %%
def data_cleaning(filename):
    """
    남산 도서관 장서 CSV 데이터 전처리 함수

    :param filename: CSV 파일이름
    """
    # 파일을 데이터프레임으로 읽습니다.
    ns_df = pd.read_csv(filename, low_memory=False)
    # NaN인 열을 삭제합니다.
    ns_book = ns_df.dropna(axis=1, how='all')

    # 대출건수를 합치기 위해 필요한 행만 추출하여 count_df 데이터프레임을 만듭니다.
    count_df = ns_book[['도서명','저자','ISBN','권','대출건수']]
    # 도서명, 저자, ISBN, 권을 기준으로 대출건수를 groupby합니다.
    loan_count = count_df.groupby(by=['도서명','저자','ISBN','권'], dropna=False).sum()
    # 원본 데이터프레임에서 중복된 행을 제외하고 고유한 행만 추출하여 복사합니다.
    dup_rows = ns_book.duplicated(subset=['도서명','저자','ISBN','권']) #중복된 행
    unique_rows = ~dup_rows #중복된 행의 반대
    ns_book3 = ns_book[unique_rows].copy() #ns_book과는 다른 저장소에 카피
    # 도서명, 저자, ISBN, 권을 인덱스로 설정합니다.
    ns_book3.set_index(['도서명','저자','ISBN','권'], inplace=True)
    # load_count에 저장된 누적 대출건수를 업데이트합니다.
    ns_book3.update(loan_count)

    # 인덱스를 재설정합니다.
    ns_book4 = ns_book3.reset_index()
    # 원본 데이터프레임의 열 순서로 변경합니다.
    ns_book4 = ns_book4[ns_book.columns]

    return ns_book4

# %% [markdown]
# 확인문제
#
# 1. col2열만 삭제하는 명령은 df.drop(axis=1,'col2')
# 2. col1열의 합을 계산하는 명령이 아닌 것은 df.loc[:,[False,False,Tru].sum()
# 3. 3번째 행을 골라내는 명령이 아닌 것은 df[df['col3']>100]
# 4. 중복된 열을 삭제하는 명령이 아닌 것은 df[~df.duplicated(keep='last')]
# 5. groupby메서드로 col3을 올바르게 더하지 못한 것은 group~~
